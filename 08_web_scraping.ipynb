# %%
import requests  # [+] HTTP 요청
from bs4 import BeautifulSoup  # [+] 웹스크래핑
import pandas as pd

# %%
# 1. User-Agent 설정
# 우리가 실제 크롬 브라우저를 사용하는 일반 사용자인 것처럼 서버를 속이는 '위장 신분증' 역할
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

search_keyword = '컴퓨터'  # [+] 검색 키워드
url = f'https://search.naver.com/search.naver?where=news&query={search_keyword}'  # 검색한 웹페이지 주소

# %%
# 2. 페이지 요청 및 파싱
res = requests.get(url, headers=headers)  # [+] 네이버 서버에 페이지 정보 요청(GET)
res.raise_for_status() # 서버가 응답을 잘 주었는지 확인(정상 200, 페이지 없음 404 등)
soup = BeautifulSoup(res.text, 'html.parser')  # [+] BeautifulSoup 객체 생성

# %%
res.text

# %%
# 3. 질문자님이 찾은 클래스로 타겟팅 (띄어쓰기를 '.'으로 변경)
# [+] 찾고자 하는 HTML 태그 정의
target_class = 'span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1.sds-comps-text-type-headline1'
title_spans = soup.select(target_class) # [+] 조건에 맞는 모든 태그를 찾아 리스트로 저장

extracted_data = []

# %%
title_spans[0].text.strip()
# Out:
# '백팩 출시한 한글과컴퓨터...“소프트웨어 브랜드의 새로운 경험 제공”'

# %%
# 4. 데이터 추출
for span in title_spans:
    # [+] 기사 제목 추출
    title = span.text.strip()
    
    # [+] 기사 링크 추출: 제목(span)을 클릭 가능하게 만드는 부모 <a> 태그를 역추적하여 찾음
    parent_a_tag = span.find_parent('a')
    link = parent_a_tag['href'] if parent_a_tag and parent_a_tag.has_attr('href') else "링크 없음"
    
    extracted_data.append({
        '제목': title,
        '링크': link
    })

# %%
extracted_data
# Out:
# [{'제목': '백팩 출시한 한글과컴퓨터...“소프트웨어 브랜드의 새로운 경험 제공”',
#   '링크': 'https://www.mk.co.kr/article/12015143'},
#  {'제목': 'SBS아카데미컴퓨터학원, ‘2026 웹툰 세미나’ 개최',
#   '링크': 'http://www.edaily.co.kr/news/newspath.asp?newsid=03099606645416120'},
#  {'제목': '양주시, 청렴 문화 조성을 위한 컴퓨터 바탕화면 제작',
#   '링크': 'https://gg.newdaily.co.kr/site/data/html/2026/04/14/2026041400183.html'},
#  {'제목': '동국대 컴퓨터·AI학부 임상수 교수팀, 인공지능 기반 약물 반응 예측 모...',
#   '링크': 'https://edu.donga.com/news/articleView.html?idxno=106245'},
#  {'제목': "인천폴리텍대 컴퓨터공학과, '한이음 드림업' 공모 선정",
#   '링크': 'https://www.newsis.com/view/NISX20260413_0003589288'},
#  {'제목': '대한정형외과 컴퓨터수술학회, 로봇 인공관절 심포지엄 개최… AI 접목 ...',
#   '링크': 'https://view.asiae.co.kr/article/2026041315323887006'},
#  {'제목': '양자컴퓨터 공포에도 BTC 버틴 이유…번스타인 "리스크 선반영됐다"',
#   '링크': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=656654'},
#  {'제목': '[카드뉴스] 양자컴퓨터가 비트코인을 해킹한다고?',
#   '링크': 'https://zdnet.co.kr/view/?no=20260413150402'},
#  {'제목': '이범수, 이혼 후 근황 보니…혼잣말 일상→컴퓨터 전원도 난관 (‘미우...',
#   '링크': 'https://isplus.com/article/view/isp202604120044'},
#  {'제목': '정형외과 컴퓨터수술학회, ‘인공관절 심포지엄’',
#   '링크': 'https://www.dailymedi.com/news/news_view.php?wr_id=935632'},
#  {'제목': '백팩 출시한 한글과컴퓨터...“소프트웨어 브랜드의 새로운 경험 제공”',
#   '링크': 'https://www.mk.co.kr/article/12015143'},
#  {'제목': 'SBS아카데미컴퓨터학원, ‘2026 웹툰 세미나’ 개최',
#   '링크': 'http://www.edaily.co.kr/news/newspath.asp?newsid=03099606645416120'},
#  {'제목': '양주시, 청렴 문화 조성을 위한 컴퓨터 바탕화면 제작',
#   '링크': 'https://gg.newdaily.co.kr/site/data/html/2026/04/14/2026041400183.html'},
#  {'제목': '동국대 컴퓨터·AI학부 임상수 교수팀, 인공지능 기반 약물 반응 예측 모...',
#   '링크': 'https://edu.donga.com/news/articleView.html?idxno=106245'},
#  {'제목': "인천폴리텍대 컴퓨터공학과, '한이음 드림업' 공모 선정",
#   '링크': 'https://www.newsis.com/view/NISX20260413_0003589288'},
#  {'제목': '대한정형외과 컴퓨터수술학회, 로봇 인공관절 심포지엄 개최… AI 접목 ...',
#   '링크': 'https://view.asiae.co.kr/article/2026041315323887006'},
#  {'제목': '양자컴퓨터 공포에도 BTC 버틴 이유…번스타인 "리스크 선반영됐다"',
#   '링크': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=656654'},
#  {'제목': '[카드뉴스] 양자컴퓨터가 비트코인을 해킹한다고?',
#   '링크': 'https://zdnet.co.kr/view/?no=20260413150402'},
#  {'제목': '이범수, 이혼 후 근황 보니…혼잣말 일상→컴퓨터 전원도 난관 (‘미우...',
#   '링크': 'https://isplus.com/article/view/isp202604120044'},
#  {'제목': '정형외과 컴퓨터수술학회, ‘인공관절 심포지엄’',
#   '링크': 'https://www.dailymedi.com/news/news_view.php?wr_id=935632'}]

# %%
# 5. [+] DataFrame으로 변환 및 확인
df = pd.DataFrame(extracted_data)
print(f"총 {len(df)}개의 기사를 추출했습니다.\n")
display(df)
# Out:
# 총 20개의 기사를 추출했습니다.
#                                              제목  \
# 0        백팩 출시한 한글과컴퓨터...“소프트웨어 브랜드의 새로운 경험 제공”
# 1                SBS아카데미컴퓨터학원, ‘2026 웹툰 세미나’ 개최
# 2                 양주시, 청렴 문화 조성을 위한 컴퓨터 바탕화면 제작
# 3   동국대 컴퓨터·AI학부 임상수 교수팀, 인공지능 기반 약물 반응 예측 모...
# 4                인천폴리텍대 컴퓨터공학과, '한이음 드림업' 공모 선정
# 5    대한정형외과 컴퓨터수술학회, 로봇 인공관절 심포지엄 개최… AI 접목 ...
# 6         양자컴퓨터 공포에도 BTC 버틴 이유…번스타인 "리스크 선반영됐다"
# 7                    [카드뉴스] 양자컴퓨터가 비트코인을 해킹한다고?
# 8     이범수, 이혼 후 근황 보니…혼잣말 일상→컴퓨터 전원도 난관 (‘미우...
# 9                     정형외과 컴퓨터수술학회, ‘인공관절 심포지엄’
# 10       백팩 출시한 한글과컴퓨터...“소프트웨어 브랜드의 새로운 경험 제공”
# 11               SBS아카데미컴퓨터학원, ‘2026 웹툰 세미나’ 개최
# 12                양주시, 청렴 문화 조성을 위한 컴퓨터 바탕화면 제작
# 13  동국대 컴퓨터·AI학부 임상수 교수팀, 인공지능 기반 약물 반응 예측 모...
# 14               인천폴리텍대 컴퓨터공학과, '한이음 드림업' 공모 선정
# 15   대한정형외과 컴퓨터수술학회, 로봇 인공관절 심포지엄 개최… AI 접목 ...
# 16        양자컴퓨터 공포에도 BTC 버틴 이유…번스타인 "리스크 선반영됐다"
# 17                   [카드뉴스] 양자컴퓨터가 비트코인을 해킹한다고?
# 18    이범수, 이혼 후 근황 보니…혼잣말 일상→컴퓨터 전원도 난관 (‘미우...
# 19                    정형외과 컴퓨터수술학회, ‘인공관절 심포지엄’
#
#                                                    링크
# 0               https://www.mk.co.kr/article/12015143
# 1   http://www.edaily.co.kr/news/newspath.asp?news...
# 2   https://gg.newdaily.co.kr/site/data/html/2026/...
# 3   https://edu.donga.com/news/articleView.html?id...
# 4   https://www.newsis.com/view/NISX20260413_00035...
# 5   https://view.asiae.co.kr/article/2026041315323...
# 6   https://www.digitaltoday.co.kr/news/articleVie...
# 7         https://zdnet.co.kr/view/?no=20260413150402
# 8     https://isplus.com/article/view/isp202604120044
# 9   https://www.dailymedi.com/news/news_view.php?w...
# 10              https://www.mk.co.kr/article/12015143
# 11  http://www.edaily.co.kr/news/newspath.asp?news...
# 12  https://gg.newdaily.co.kr/site/data/html/2026/...
# 13  https://edu.donga.com/news/articleView.html?id...
# 14  https://www.newsis.com/view/NISX20260413_00035...
# 15  https://view.asiae.co.kr/article/2026041315323...
# 16  https://www.digitaltoday.co.kr/news/articleVie...
# 17        https://zdnet.co.kr/view/?no=20260413150402
# 18    https://isplus.com/article/view/isp202604120044
# 19  https://www.dailymedi.com/news/news_view.php?w...
